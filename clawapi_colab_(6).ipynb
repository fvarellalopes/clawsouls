# %% [markdown]
# <a href="https://colab.research.google.com/github/fvarellalopes/clawsouls/blob/main/clawapi_colab_(6).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🎨 ClawSouls — Avatar API Server (FastAPI + Cloudflared)
#
# Sobe um servidor **FastAPI** no Colab que gera avatares por requisição HTTP.
#
# **Fluxo:**
# 1. Rode este notebook (com GPU)
# 2. Copie a URL pública do Cloudflared
# 3. Envie POST `/generate` com os atributos da soul
# 4. Receba a imagem gerada em base64
#
# ---

# %% [markdown]
# ## Pré-requisitos
#
# - `Runtime > Change runtime type > T4 GPU`
# - Não precisa do repositório clonado (tudo é self-contained)

# %%
# ═══════════════════════════════════════════════════════════
# TOGGLE DE MODELO
# ═══════════════════════════════════════════════════════════

MODELO = "sdxl"          # ← "sdxl" ou "turbo"
SECRET_TOKEN = "cs-secret-2026"  # ← Troque para algo seguro!
TOTAL_STEPS = 15          # Override global de steps
TOTAL_GUIDANCE = 7.5      # Override global de guidance

CATALOGO = {
    "turbo": {
        "model_id": "Tongyi-MAI/Z-Image-Turbo",
        "width": 512, "height": 768, "variant": "fp16",
        "default_steps": 4, "default_guidance": 1.0,
    },
    "sdxl": {
        "model_id": "stabilityai/stable-diffusion-xl-base-1.0",
        "width": 512, "height": 768, "variant": "fp16",
        "default_steps": 25, "default_guidance": 7.5,
    },
}

assert MODELO in CATALOGO, f"Use: {list(CATALOGO.keys())}"
cfg = CATALOGO[MODELO]
MODEL_ID = cfg["model_id"]

print(f"🔧 Modelo: {MODELO} ({MODEL_ID})")
print(f"   Steps: {TOTAL_STEPS}, Guidance: {TOTAL_GUIDANCE}, Token: {SECRET_TOKEN[:4]}...")
# Out:
# 🔧 Modelo: sdxl (stabilityai/stable-diffusion-xl-base-1.0)
#    Steps: 15, Guidance: 7.5, Token: cs-s...

# %%
# Escreve o servidor num arquivo .py para que o uvicorn consira importá-lo corretamente.
# O notebook não serve como módulo para o uvicorn (--reload).

import textwrap
 # Silenciar warnings de Flax
import warnings, os
warnings.filterwarnings("ignore", category=DeprecationWarning)
os.environ["TRANSFORMERS_VERBOSITY"] = "error"

# !pip install -q fastapi uvicorn[standard] pydantic pillow
# !pip install -q diffusers[torch] transformers accelerate torch torchvision safetensors

# cloudflared não está no PyPI — baixa o binário direto do GitHub
# !wget -q https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64 -O /usr/local/bin/cloudflared
# !chmod +x /usr/local/bin/cloudflared

print("✅ Dependências instaladas!")

server_code = textwrap.dedent('''
    from urllib.parse import parse_qs
    import io, base64, time, os, re
    from datetime import datetime
    from typing import Optional

    from pydantic import BaseModel
    from fastapi import FastAPI, HTTPException, Header, Request
    import torch
    from diffusers import AutoPipelineForText2Image

    # ── Config (injetadas pelo notebook via env vars) ──────────
    MODELO = os.environ.get('CLAWSOULS_MODELO', 'sdxl')
    SECRET_TOKEN = os.environ.get('CLAWSOULS_SECRET', 'cs-secret-2026')
    TOTAL_STEPS = int(os.environ.get('CLAWSOULS_STEPS', '15'))
    TOTAL_GUIDANCE = float(os.environ.get('CLAWSOULS_GUIDANCE', '7.5'))
    MODEL_ID = os.environ.get('CLAWSOULS_MODEL_ID', 'stabilityai/stable-diffusion-xl-base-1.0')
    MODEL_WIDTH = int(os.environ.get('CLAWSOULS_WIDTH', '512'))
    MODEL_HEIGHT = int(os.environ.get('CLAWSOULS_HEIGHT', '768'))

    # ── Prompt Engine ────────────────────────────────────────
    EMOJI_HINTS = {
        '🔬': 'scientific goggles, lab coat details',
        '🕵️': 'detective hat, trench coat',
        '🌟': 'sparkles, star-shaped accessories',
        '⚡': 'electric energy aura, lightning motifs',
        '🧘': 'lotus position, meditation beads, serene',
        '🤖': 'mechanical parts, circuit patterns',
        '🏴‍☠️': 'pirate bandana, adventurous look',
        '💻': 'techwear, holographic screen elements',
        '🎤': 'microphone, stage lights, glamorous',
        '🌳': 'nature elements, leaves, organic flowing design',
        '🕶️': 'sunglasses, cool demeanor',
        '😈': 'mischievous grin, horns, dark aesthetic',
        '👽': 'alien features, cosmic glow',
        '🐉': 'dragon scales, mythical aura',
        '🦊': 'fox ears, cunning expression',
        '🐱': 'cat ears, playful whiskers',
        '👁️': 'mystical third eye, all-seeing aura',
        '💀': 'skull motifs, dark mysticism',
        '🎭': 'theater mask, dramatic duality',
    }

    DOMAIN_ACCENTS = {
        'tech': 'circuit patterns, holographic UI elements',
        'philosophy': 'ancient scrolls, ethereal glow',
        'science': 'molecular structures, lab equipment details',
        'arts': 'paint splashes, creative chaos',
        'history': 'ancient runes, time-worn textures',
        'literature': 'floating text, book pages',
        'pop-culture': 'retro gaming elements, neon signs',
        'sports': 'athletic build, competitive energy',
        'business': 'sharp suit, corporate confidence',
        'psychology': 'thoughtful gaze, abstract mind visuals',
    }

    def build_prompt(soul: dict) -> str:
        creature = soul.get('creature', 'mysterious entity')
        vibe = soul.get('vibe', 'enigmatic')
        emoji = soul.get('emoji', '')
        humor = soul.get('humor', 50)
        formality = soul.get('formality', 50)
        vibe_style = soul.get('vibeStyle', 'concise')
        knowledge_domains = soul.get('knowledgeDomains', [])
        emotional_range = soul.get('emotionalRange', 50)
        agreeableness = soul.get('agreeableness', 50)
        extraversion = soul.get('extraversion', 50)
        openness = soul.get('openness', 70)
        neuroticism = soul.get('neuroticism', 30)
        is_high_formality = formality > 65
        is_playful = humor > 65
        is_minimal = vibe_style == 'minimal'
        is_concise = vibe_style == 'concise'
        is_dramatic = emotional_range > 75 or vibe_style == 'dramatic'
        is_tech = any(d in ('tech', 'science') for d in knowledge_domains)
        art_style = 'cyberpunk digital illustration'
        if is_high_formality:
            art_style = 'elegant digital painting, Renaissance lighting'
        elif is_playful:
            art_style = 'colorful anime-inspired digital art, vibrant'
        elif is_minimal:
            art_style = 'minimalist vector art, clean lines, geometric'
        elif is_tech:
            art_style = 'sci-fi concept art, holographic elements'
        elif is_dramatic:
            art_style = 'cinematic digital painting, dramatic chiaroscuro lighting'
        atmosphere = 'dark atmospheric background with neon accents'
        if agreeableness > 70:
            atmosphere = 'warm, inviting background with soft golden light'
        elif neuroticism > 60:
            atmosphere = 'unstable, glitching background with fractured light'
        elif extraversion > 70:
            atmosphere = 'dynamic, energetic background with bold colors'
        elif openness > 75:
            atmosphere = 'dreamy, surreal background with cosmic elements'
        expression = 'calm, confident expression'
        if neuroticism > 60:
            expression = 'tense, alert expression'
        elif extraversion > 70:
            expression = 'bright, engaging smile'
        elif agreeableness > 70:
            expression = 'gentle, warm expression'
        elif openness > 70:
            expression = 'curious, contemplative gaze'
        elif humor > 70:
            expression = 'sly, playful smirk'
        descriptors = [creature, vibe]
        if expression != 'calm, confident expression':
            descriptors.append(expression)
        descriptors.append(art_style)
        if not is_concise and not is_minimal:
            descriptors.append('vibe: ' + vibe_style)
        if emoji and emoji in EMOJI_HINTS:
            descriptors.append(EMOJI_HINTS[emoji])
        for domain in knowledge_domains:
            if domain in DOMAIN_ACCENTS:
                descriptors.append(DOMAIN_ACCENTS[domain])
        descriptors.append('unique, one-of-a-kind character design')
        prompt = (
            'close-up portrait, centered, detailed face, '
            + 'professional character art of ' + creature + ', '
            + ', '.join(descriptors[1:]) + ', '
            + atmosphere + ', highly detailed, 4k, masterpiece'
        )
        return prompt.strip()

    def build_negative_prompt() -> str:
        return (
            'blurry, low quality, deformed, ugly, duplicate, disfigured, '
            'bad anatomy, bad proportions, extra limbs, mutated hands, '
            'text, watermark, signature, logo, '
            'photorealistic, 3d render, '
            'nude, NSFW, gore'
        )

    # ── FastAPI App ────────────────────────────────────────
    class GenerateRequest(BaseModel):
        name: str
        creature: Optional[str] = 'mysterious entity'
        vibe: Optional[str] = 'enigmatic'
        emoji: Optional[str] = ''
        humor: Optional[int] = 50
        formality: Optional[int] = 50
        emojiUsage: Optional[int] = 20
        knowledgeDomains: Optional[list] = []
        emotionalRange: Optional[int] = 50
        vibeStyle: Optional[str] = 'concise'
        agreeableness: Optional[int] = 50
        extraversion: Optional[int] = 50
        openness: Optional[int] = 70
        neuroticism: Optional[int] = 30
        steps: Optional[int] = None
        guidance: Optional[float] = None
        custom_prompt: Optional[str] = None

    app = FastAPI(title='ClawSouls Avatar API', version='2.0')

    def _check_token(request: Request) -> bool:
        auth = request.headers.get('Authorization', '')
        if auth == 'Bearer ' + SECRET_TOKEN:
            return True
        qs = parse_qs(request.url.query)
        if qs.get('token', [''])[0] == SECRET_TOKEN:
            return True
        if request.headers.get('X-Token') == SECRET_TOKEN:
            return True
        return False

    @app.get('/health')
    def health():
        return {'status': 'ok', 'model': MODELO, 'model_id': MODEL_ID}

    @app.get('/models')
    def list_models():
        return {'available': {}, 'current': MODELO}

    @app.post('/generate')
    async def generate(request: Request, req: GenerateRequest):
        if not _check_token(request):
            raise HTTPException(status_code=401, detail='Unauthorized')
        if req.custom_prompt:
            prompt = req.custom_prompt
        else:
            d = req.dict()
            d.pop('steps', None)
            d.pop('guidance', None)
            d.pop('custom_prompt', None)
            prompt = build_prompt(d)
        negative = build_negative_prompt()
        steps = req.steps if req.steps else TOTAL_STEPS
        guidance = req.guidance if req.guidance else TOTAL_GUIDANCE
        print(f"[{datetime.now().strftime('%H:%M:%S')}] Generating: {req.name} ({steps} steps)")
        start = time.time()
        generator = torch.Generator(device='cuda').manual_seed(int(time.time() * 1000) % (2**32))
        image = pipe(
            prompt=prompt, negative_prompt=negative,
            num_inference_steps=steps, guidance_scale=guidance,
            width=MODEL_WIDTH, height=MODEL_HEIGHT, generator=generator,
        ).images[0]
        elapsed = time.time() - start
        buf = io.BytesIO()
        image.save(buf, format='PNG')
        buf.seek(0)
        img_b64 = base64.b64encode(buf.read()).decode('utf-8')
        safe_name = ''.join(c if c.isalnum() or c in '._-' else '_' for c in req.name.lower().strip())
        print(f"   ✅ {req.name} → {elapsed:.1f}s")
        return {
            'name': req.name, 'slug': safe_name, 'prompt': prompt,
            'negative_prompt': negative, 'seed': int(generator.initial_seed()),
            'steps': steps, 'guidance': guidance, 'model': MODELO,
            'elapsed_s': round(elapsed, 1), 'image_base64': img_b64,
        }

    # ── Lifespan (model loading) ─────────────────────────────
    from contextlib import asynccontextmanager

    @asynccontextmanager
    async def lifespan(app):
        global pipe
        variant = os.environ.get('CLAWSOULS_VARIANT', 'fp16')
        pipe = AutoPipelineForText2Image.from_pretrained(
            MODEL_ID,
            torch_dtype=torch.float16 if variant == 'fp16' else torch.float32,
            variant=variant if variant != 'fp32' else None,
            use_safetensors=True,
        )
        pipe.enable_attention_slicing()
        if hasattr(pipe, 'enable_vae_tiling'):
            pipe.enable_vae_tiling()
        pipe.to('cuda')
        # Fix: forçar VAE no mesmo dtype pra evitar RuntimeError de mixed precision
        if hasattr(pipe, 'vae'):
            pipe.vae.to(torch_device='cuda', torch_dtype=torch.float16)
        print('✅ Modelo carregado: ' + MODEL_ID)
        yield
        del pipe
        torch.cuda.empty_cache()
        print('🛑 Servidor encerrado')

    app.router.lifespan_context = lifespan

''')

# Injecta config do notebook como env vars pro server.py ler
import os as _os
_os.environ['CLAWSOULS_MODELO'] = MODELO
_os.environ['CLAWSOULS_SECRET'] = SECRET_TOKEN
_os.environ['CLAWSOULS_STEPS'] = str(TOTAL_STEPS)
_os.environ['CLAWSOULS_GUIDANCE'] = str(TOTAL_GUIDANCE)
_os.environ['CLAWSOULS_MODEL_ID'] = MODEL_ID
_os.environ['CLAWSOULS_WIDTH'] = str(cfg['width'])
_os.environ['CLAWSOULS_HEIGHT'] = str(cfg['height'])
_os.environ['CLAWSOULS_VARIANT'] = cfg['variant']

# Grava o server.py
with open('/content/server.py', 'w') as f:
    f.write(server_code)

print('✅ server.py gravado!')
# Out:
# ✅ Dependências instaladas!
# ✅ server.py gravado!

# %%
# Inicia uvicorn rodando server.py em background
uvicorn_proc = !nohup python3 -m uvicorn server:app --host 0.0.0.0 --port 8000 --log-level warning > /tmp/uvicorn.log 2>&1 &

# Healthcheck: espera o servidor responder antes de subir o tunnel
import time, urllib.request

print('⏳ Esperando servidor iniciar...')
server_ok = False
for i in range(60):
    try:
        urllib.request.urlopen('http://localhost:8000/health', timeout=2)
        server_ok = True
        print('✅ Servidor ativo!')
        break
    except Exception as e:
        time.sleep(1)

if not server_ok:
    print('⚠️  Servidor não respondeu em 30s!')
    # !cat /tmp/uvicorn.log
# Out:
# ⏳ Esperando servidor iniciar...
# ⚠️  Servidor não respondeu em 30s!
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_validators.py:205: UserWarning: The `local_dir_use_symlinks` argument is deprecated and ignored in `hf_hub_download`. Downloading to a local directory does not use symlinks anymore.
#   warnings.warn(
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/196 [00:00<?, ?it/s]
# Loading weights:   1%|          | 1/196 [00:00<00:00, 12826.62it/s, Materializing param=text_model.embeddings.position_embedding.weight]
# Loading weights:   1%|          | 1/196 [00:00<00:00, 5497.12it/s, Materializing param=text_model.embeddings.position_embedding.weight]
# Loading weights:   1%|          | 2/196 [00:00<00:00, 5124.38it/s, Materializing param=text_model.embeddings.token_embedding.weight]
# Loading weights:   1%|          | 2/196 [00:00<00:00, 3821.69it/s, Materializing param=text_model.embeddings.token_embedding.weight]
# Loading weights:   2%|▏         | 3/196 [00:00<00:00, 4291.58it/s, Materializing param=text_model.encoder.layers.0.layer_norm1.bias]
# Loading weights:   2%|▏         | 3/196 [00:00<00:00, 3775.25it/s, Materializing param=text_model.encoder.layers.0.layer_norm1.bias]
# Loading weights:   2%|▏         | 4/196 [00:00<00:00, 4201.66it/s, Materializing param=text_model.encoder.layers.0.layer_norm1.weight]
# Loading weights:   2%|▏         | 4/196 [00:00<00:00, 3847.99it/s, Materializing param=text_model.encoder.layers.0.layer_norm1.weight]
# Loading weights:   3%|▎         | 5/196 [00:00<00:00, 4210.30it/s, Materializing param=text_model.encoder.layers.0.layer_norm2.bias]
# Loading weights:   3%|▎         | 5/196 [00:00<00:00, 3914.79it/s, Materializing param=text_model.encoder.layers.0.layer_norm2.bias]
# Loading weights:   3%|▎         | 6/196 [00:00<00:00, 4131.64it/s, Materializing param=text_model.encoder.layers.0.layer_norm2.weight]
# Loading weights:   3%|▎         | 6/196 [00:00<00:00, 3853.29it/s, Materializing param=text_model.encoder.layers.0.layer_norm2.weight]
# Loading weights:   4%|▎         | 7/196 [00:00<00:00, 4083.47it/s, Materializing param=text_model.encoder.layers.0.mlp.fc1.bias]
# Loading weights:   4%|▎         | 7/196 [00:00<00:00, 3885.67it/s, Materializing param=text_model.encoder.layers.0.mlp.fc1.bias]
# Loading weights:   4%|▍         | 8/196 [00:00<00:00, 4103.51it/s, Materializing param=text_model.encoder.layers.0.mlp.fc1.weight]
# Loading weights:   4%|▍         | 8/196 [00:00<00:00, 3934.16it/s, Materializing param=text_model.encoder.layers.0.mlp.fc1.weight]
# Loading weights:   5%|▍         | 9/196 [00:00<00:00, 4132.77it/s, Materializing param=text_model.encoder.layers.0.mlp.fc2.bias]
# Loading weights:   5%|▍         | 9/196 [00:00<00:00, 3978.16it/s, Materializing param=text_model.encoder.layers.0.mlp.fc2.bias]
# Loading weights:   5%|▌         | 10/196 [00:00<00:00, 4115.69it/s, Materializing param=text_model.encoder.layers.0.mlp.fc2.weight]
# Loading weights:   5%|▌         | 10/196 [00:00<00:00, 3958.38it/s, Materializing param=text_model.encoder.layers.0.mlp.fc2.weight]
# Loading weights:   6%|▌         | 11/196 [00:00<00:00, 4102.56it/s, Materializing param=text_model.encoder.layers.0.self_attn.k_proj.bias]
# Loading weights:   6%|▌         | 11/196 [00:00<00:00, 3975.64it/s, Materializing param=text_model.encoder.layers.0.self_attn.k_proj.bias]
# Loading weights:   6%|▌         | 12/196 [00:00<00:00, 4117.11it/s, Materializing param=text_model.encoder.layers.0.self_attn.k_proj.weight]
# Loading weights:   6%|▌         | 12/196 [00:00<00:00, 3983.19it/s, Materializing param=text_model.encoder.layers.0.self_attn.k_proj.weight]
# Loading weights:   7%|▋         | 13/196 [00:00<00:00, 4109.89it/s, Materializing param=text_model.encoder.layers.0.self_attn.out_proj.bias]
# Loading weights:   7%|▋         | 13/196 [00:00<00:00, 3996.33it/s, Materializing param=text_model.encoder.layers.0.self_attn.out_proj.bias]
# Loading weights:   7%|▋         | 14/196 [00:00<00:00, 4096.57it/s, Materializing param=text_model.encoder.layers.0.self_attn.out_proj.weight]
# Loading weights:   7%|▋         | 14/196 [00:00<00:00, 3974.84it/s, Materializing param=text_model.encoder.layers.0.self_attn.out_proj.weight]
# Loading weights:   8%|▊         | 15/196 [00:00<00:00, 4066.88it/s, Materializing param=text_model.encoder.layers.0.self_attn.q_proj.bias]
# Loading weights:   8%|▊         | 15/196 [00:00<00:00, 3973.13it/s, Materializing param=text_model.encoder.layers.0.self_attn.q_proj.bias]
# Loading weights:   8%|▊         | 16/196 [00:00<00:00, 4079.07it/s, Materializing param=text_model.encoder.layers.0.self_attn.q_proj.weight]
# Loading weights:   8%|▊         | 16/196 [00:00<00:00, 3991.49it/s, Materializing param=text_model.encoder.layers.0.self_attn.q_proj.weight]
# Loading weights:   9%|▊         | 17/196 [00:00<00:00, 4093.18it/s, Materializing param=text_model.encoder.layers.0.self_attn.v_proj.bias]
# Loading weights:   9%|▊         | 17/196 [00:00<00:00, 4012.78it/s, Materializing param=text_model.encoder.layers.0.self_attn.v_proj.bias]
# Loading weights:   9%|▉         | 18/196 [00:00<00:00, 4107.81it/s, Materializing param=text_model.encoder.layers.0.self_attn.v_proj.weight]
# Loading weights:   9%|▉         | 18/196 [00:00<00:00, 4005.81it/s, Materializing param=text_model.encoder.layers.0.self_attn.v_proj.weight]
# Loading weights:  10%|▉         | 19/196 [00:00<00:00, 4086.34it/s, Materializing param=text_model.encoder.layers.1.layer_norm1.bias]
# Loading weights:  10%|▉         | 19/196 [00:00<00:00, 4012.07it/s, Materializing param=text_model.encoder.layers.1.layer_norm1.bias]
# Loading weights:  10%|█         | 20/196 [00:00<00:00, 4098.20it/s, Materializing param=text_model.encoder.layers.1.layer_norm1.weight]
# Loading weights:  10%|█         | 20/196 [00:00<00:00, 4029.30it/s, Materializing param=text_model.encoder.layers.1.layer_norm1.weight]
# Loading weights:  11%|█         | 21/196 [00:00<00:00, 4114.75it/s, Materializing param=text_model.encoder.layers.1.layer_norm2.bias]
# Loading weights:  11%|█         | 21/196 [00:00<00:00, 4048.00it/s, Materializing param=text_model.encoder.layers.1.layer_norm2.bias]
# Loading weights:  11%|█         | 22/196 [00:00<00:00, 4125.85it/s, Materializing param=text_model.encoder.layers.1.layer_norm2.weight]
# Loading weights:  11%|█         | 22/196 [00:00<00:00, 4046.60it/s, Materializing param=text_model.encoder.layers.1.layer_norm2.weight]
# Loading weights:  12%|█▏        | 23/196 [00:00<00:00, 4108.74it/s, Materializing param=text_model.encoder.layers.1.mlp.fc1.bias]
# Loading weights:  12%|█▏        | 23/196 [00:00<00:00, 4047.20it/s, Materializing param=text_model.encoder.layers.1.mlp.fc1.bias]
# Loading weights:  12%|█▏        | 24/196 [00:00<00:00, 4118.79it/s, Materializing param=text_model.encoder.layers.1.mlp.fc1.weight]
# Loading weights:  12%|█▏        | 24/196 [00:00<00:00, 4059.66it/s, Materializing param=text_model.encoder.layers.1.mlp.fc1.weight]
# Loading weights:  13%|█▎        | 25/196 [00:00<00:00, 4126.46it/s, Materializing param=text_model.encoder.layers.1.mlp.fc2.bias]
# Loading weights:  13%|█▎        | 25/196 [00:00<00:00, 4069.93it/s, Materializing param=text_model.encoder.layers.1.mlp.fc2.bias]
# Loading weights:  13%|█▎        | 26/196 [00:00<00:00, 4133.26it/s, Materializing param=text_model.encoder.layers.1.mlp.fc2.weight]
# Loading weights:  13%|█▎        | 26/196 [00:00<00:00, 4072.75it/s, Materializing param=text_model.encoder.layers.1.mlp.fc2.weight]
# Loading weights:  14%|█▍        | 27/196 [00:00<00:00, 4109.23it/s, Materializing param=text_model.encoder.layers.1.self_attn.k_proj.bias]
# Loading weights:  14%|█▍        | 27/196 [00:00<00:00, 4054.64it/s, Materializing param=text_model.encoder.layers.1.self_attn.k_proj.bias]
# Loading weights:  14%|█▍        | 28/196 [00:00<00:00, 4112.64it/s, Materializing param=text_model.encoder.layers.1.self_attn.k_proj.weight]
# Loading weights:  14%|█▍        | 28/196 [00:00<00:00, 4060.59it/s, Materializing param=text_model.encoder.layers.1.self_attn.k_proj.weight]
# Loading weights:  15%|█▍        | 29/196 [00:00<00:00, 4091.73it/s, Materializing param=text_model.encoder.layers.1.self_attn.out_proj.bias]
# Loading weights:  15%|█▍        | 29/196 [00:00<00:00, 4032.45it/s, Materializing param=text_model.encoder.layers.1.self_attn.out_proj.bias]
# Loading weights:  15%|█▌        | 30/196 [00:00<00:00, 4062.80it/s, Materializing param=text_model.encoder.layers.1.self_attn.out_proj.weight]
# Loading weights:  15%|█▌        | 30/196 [00:00<00:00, 3986.10it/s, Materializing param=text_model.encoder.layers.1.self_attn.out_proj.weight]
# Loading weights:  16%|█▌        | 31/196 [00:00<00:00, 4010.35it/s, Materializing param=text_model.encoder.layers.1.self_attn.q_proj.bias]
# Loading weights:  16%|█▌        | 31/196 [00:00<00:00, 3959.30it/s, Materializing param=text_model.encoder.layers.1.self_attn.q_proj.bias]
# Loading weights:  16%|█▋        | 32/196 [00:00<00:00, 3992.08it/s, Materializing param=text_model.encoder.layers.1.self_attn.q_proj.weight]
# Loading weights:  16%|█▋        | 32/196 [00:00<00:00, 3945.03it/s, Materializing param=text_model.encoder.layers.1.self_attn.q_proj.weight]
# Loading weights:  17%|█▋        | 33/196 [00:00<00:00, 3974.39it/s, Materializing param=text_model.encoder.layers.1.self_attn.v_proj.bias]
# Loading weights:  17%|█▋        | 33/196 [00:00<00:00, 3926.81it/s, Materializing param=text_model.encoder.layers.1.self_attn.v_proj.bias]
# Loading weights:  17%|█▋        | 34/196 [00:00<00:00, 3943.43it/s, Materializing param=text_model.encoder.layers.1.self_attn.v_proj.weight]
# Loading weights:  17%|█▋        | 34/196 [00:00<00:00, 3895.60it/s, Materializing param=text_model.encoder.layers.1.self_attn.v_proj.weight]
# Loading weights:  18%|█▊        | 35/196 [00:00<00:00, 3919.07it/s, Materializing param=text_model.encoder.layers.2.layer_norm1.bias]
# Loading weights:  18%|█▊        | 35/196 [00:00<00:00, 3874.70it/s, Materializing param=text_model.encoder.layers.2.layer_norm1.bias]
# Loading weights:  18%|█▊        | 36/196 [00:00<00:00, 3902.28it/s, Materializing param=text_model.encoder.layers.2.layer_norm1.weight]
# Loading weights:  18%|█▊        | 36/196 [00:00<00:00, 3857.32it/s, Materializing param=text_model.encoder.layers.2.layer_norm1.weight]
# Loading weights:  19%|█▉        | 37/196 [00:00<00:00, 3546.45it/s, Materializing param=text_model.encoder.layers.2.layer_norm2.bias]
# Loading weights:  19%|█▉        | 37/196 [00:00<00:00, 3503.62it/s, Materializing param=text_model.encoder.layers.2.layer_norm2.bias]
# Loading weights:  19%|█▉        | 38/196 [00:00<00:00, 3530.72it/s, Materializing param=text_model.encoder.layers.2.layer_norm2.weight]
# Loading weights:  19%|█▉        | 38/196 [00:00<00:00, 3496.71it/s, Materializing param=text_model.encoder.layers.2.layer_norm2.weight]
# Loading weights:  20%|█▉        | 39/196 [00:00<00:00, 3529.42it/s, Materializing param=text_model.encoder.layers.2.mlp.fc1.bias]
# Loading weights:  20%|█▉        | 39/196 [00:00<00:00, 3498.47it/s, Materializing param=text_model.encoder.layers.2.mlp.fc1.bias]
# Loading weights:  20%|██        | 40/196 [00:00<00:00, 3528.18it/s, Materializing param=text_model.encoder.layers.2.mlp.fc1.weight]
# Loading weights:  20%|██        | 40/196 [00:00<00:00, 3482.56it/s, Materializing param=text_model.encoder.layers.2.mlp.fc1.weight]
# Loading weights:  21%|██        | 41/196 [00:00<00:00, 3506.23it/s, Materializing param=text_model.encoder.layers.2.mlp.fc2.bias]
# Loading weights:  21%|██        | 41/196 [00:00<00:00, 3474.77it/s, Materializing param=text_model.encoder.layers.2.mlp.fc2.bias]
# Loading weights:  21%|██▏       | 42/196 [00:00<00:00, 3502.90it/s, Materializing param=text_model.encoder.layers.2.mlp.fc2.weight]
# Loading weights:  21%|██▏       | 42/196 [00:00<00:00, 3474.50it/s, Materializing param=text_model.encoder.layers.2.mlp.fc2.weight]
# Loading weights:  22%|██▏       | 43/196 [00:00<00:00, 3504.35it/s, Materializing param=text_model.encoder.layers.2.self_attn.k_proj.bias]
# Loading weights:  22%|██▏       | 43/196 [00:00<00:00, 3476.05it/s, Materializing param=text_model.encoder.layers.2.self_attn.k_proj.bias]
# Loading weights:  22%|██▏       | 44/196 [00:00<00:00, 3492.54it/s, Materializing param=text_model.encoder.layers.2.self_attn.k_proj.weight]
# Loading weights:  22%|██▏       | 44/196 [00:00<00:00, 3463.63it/s, Materializing param=text_model.encoder.layers.2.self_attn.k_proj.weight]
# Loading weights:  23%|██▎       | 45/196 [00:00<00:00, 3490.21it/s, Materializing param=text_model.encoder.layers.2.self_attn.out_proj.bias]
# Loading weights:  23%|██▎       | 45/196 [00:00<00:00, 3462.87it/s, Materializing param=text_model.encoder.layers.2.self_attn.out_proj.bias]
# Loading weights:  23%|██▎       | 46/196 [00:00<00:00, 3487.17it/s, Materializing param=text_model.encoder.layers.2.self_attn.out_proj.weight]
# Loading weights:  23%|██▎       | 46/196 [00:00<00:00, 3459.16it/s, Materializing param=text_model.encoder.layers.2.self_attn.out_proj.weight]
# Loading weights:  24%|██▍       | 47/196 [00:00<00:00, 3474.92it/s, Materializing param=text_model.encoder.layers.2.self_attn.q_proj.bias]
# Loading weights:  24%|██▍       | 47/196 [00:00<00:00, 3446.67it/s, Materializing param=text_model.encoder.layers.2.self_attn.q_proj.bias]
# Loading weights:  24%|██▍       | 48/196 [00:00<00:00, 3481.23it/s, Materializing param=text_model.encoder.layers.2.self_attn.q_proj.weight]
# Loading weights:  24%|██▍       | 48/196 [00:00<00:00, 3466.07it/s, Materializing param=text_model.encoder.layers.2.self_attn.q_proj.weight]
# Loading weights:  25%|██▌       | 49/196 [00:00<00:00, 3512.28it/s, Materializing param=text_model.encoder.layers.2.self_attn.v_proj.bias]
# Loading weights:  25%|██▌       | 49/196 [00:00<00:00, 3498.47it/s, Materializing param=text_model.encoder.layers.2.self_attn.v_proj.bias]
# Loading weights:  26%|██▌       | 50/196 [00:00<00:00, 3545.24it/s, Materializing param=text_model.encoder.layers.2.self_attn.v_proj.weight]
# Loading weights:  26%|██▌       | 50/196 [00:00<00:00, 3531.75it/s, Materializing param=text_model.encoder.layers.2.self_attn.v_proj.weight]
# Loading weights:  26%|██▌       | 51/196 [00:00<00:00, 3573.44it/s, Materializing param=text_model.encoder.layers.3.layer_norm1.bias]
# Loading weights:  26%|██▌       | 51/196 [00:00<00:00, 3559.34it/s, Materializing param=text_model.encoder.layers.3.layer_norm1.bias]
# Loading weights:  27%|██▋       | 52/196 [00:00<00:00, 3581.64it/s, Materializing param=text_model.encoder.layers.3.layer_norm1.weight]
# Loading weights:  27%|██▋       | 52/196 [00:00<00:00, 3557.68it/s, Materializing param=text_model.encoder.layers.3.layer_norm1.weight]
# Loading weights:  27%|██▋       | 53/196 [00:00<00:00, 3578.58it/s, Materializing param=text_model.encoder.layers.3.layer_norm2.bias]
# Loading weights:  27%|██▋       | 53/196 [00:00<00:00, 3551.71it/s, Materializing param=text_model.encoder.layers.3.layer_norm2.bias]
# Loading weights:  28%|██▊       | 54/196 [00:00<00:00, 3573.96it/s, Materializing param=text_model.encoder.layers.3.layer_norm2.weight]
# Loading weights:  28%|██▊       | 54/196 [00:00<00:00, 3547.98it/s, Materializing param=text_model.encoder.layers.3.layer_norm2.weight]
# Loading weights:  28%|██▊       | 55/196 [00:00<00:00, 3560.09it/s, Materializing param=text_model.encoder.layers.3.mlp.fc1.bias]
# Loading weights:  28%|██▊       | 55/196 [00:00<00:00, 3534.02it/s, Materializing param=text_model.encoder.layers.3.mlp.fc1.bias]
# Loading weights:  29%|██▊       | 56/196 [00:00<00:00, 3555.25it/s, Materializing param=text_model.encoder.layers.3.mlp.fc1.weight]
# Loading weights:  29%|██▊       | 56/196 [00:00<00:00, 3533.21it/s, Materializing param=text_model.encoder.layers.3.mlp.fc1.weight]
# Loading weights:  29%|██▉       | 57/196 [00:00<00:00, 3553.86it/s, Materializing param=text_model.encoder.layers.3.mlp.fc2.bias]
# Loading weights:  29%|██▉       | 57/196 [00:00<00:00, 3531.76it/s, Materializing param=text_model.encoder.layers.3.mlp.fc2.bias]
# Loading weights:  30%|██▉       | 58/196 [00:00<00:00, 3551.49it/s, Materializing param=text_model.encoder.layers.3.mlp.fc2.weight]
# Loading weights:  30%|██▉       | 58/196 [00:00<00:00, 3524.01it/s, Materializing param=text_model.encoder.layers.3.mlp.fc2.weight]
# Loading weights:  30%|███       | 59/196 [00:00<00:00, 3538.48it/s, Materializing param=text_model.encoder.layers.3.self_attn.k_proj.bias]
# Loading weights:  30%|███       | 59/196 [00:00<00:00, 3517.36it/s, Materializing param=text_model.encoder.layers.3.self_attn.k_proj.bias]
# Loading weights:  31%|███       | 60/196 [00:00<00:00, 3536.41it/s, Materializing param=text_model.encoder.layers.3.self_attn.k_proj.weight]
# Loading weights:  31%|███       | 60/196 [00:00<00:00, 3515.07it/s, Materializing param=text_model.encoder.layers.3.self_attn.k_proj.weight]
# Loading weights:  31%|███       | 61/196 [00:00<00:00, 3530.90it/s, Materializing param=text_model.encoder.layers.3.self_attn.out_proj.bias]
# Loading weights:  31%|███       | 61/196 [00:00<00:00, 3509.64it/s, Materializing param=text_model.encoder.layers.3.self_attn.out_proj.bias]
# Loading weights:  32%|███▏      | 62/196 [00:00<00:00, 3520.66it/s, Materializing param=text_model.encoder.layers.3.self_attn.out_proj.weight]
# Loading weights:  32%|███▏      | 62/196 [00:00<00:00, 3498.97it/s, Materializing param=text_model.encoder.layers.3.self_attn.out_proj.weight]
# Loading weights:  32%|███▏      | 63/196 [00:00<00:00, 3516.28it/s, Materializing param=text_model.encoder.layers.3.self_attn.q_proj.bias]
# Loading weights:  32%|███▏      | 63/196 [00:00<00:00, 3495.39it/s, Materializing param=text_model.encoder.layers.3.self_attn.q_proj.bias]
# Loading weights:  33%|███▎      | 64/196 [00:00<00:00, 3514.89it/s, Materializing param=text_model.encoder.layers.3.self_attn.q_proj.weight]
# Loading weights:  33%|███▎      | 64/196 [00:00<00:00, 3495.71it/s, Materializing param=text_model.encoder.layers.3.self_attn.q_proj.weight]
# Loading weights:  33%|███▎      | 65/196 [00:00<00:00, 3508.21it/s, Materializing param=text_model.encoder.layers.3.self_attn.v_proj.bias]
# Loading weights:  33%|███▎      | 65/196 [00:00<00:00, 3489.17it/s, Materializing param=text_model.encoder.layers.3.self_attn.v_proj.bias]
# Loading weights:  34%|███▎      | 66/196 [00:00<00:00, 3507.30it/s, Materializing param=text_model.encoder.layers.3.self_attn.v_proj.weight]
# Loading weights:  34%|███▎      | 66/196 [00:00<00:00, 3488.78it/s, Materializing param=text_model.encoder.layers.3.self_attn.v_proj.weight]
# Loading weights:  34%|███▍      | 67/196 [00:00<00:00, 3510.05it/s, Materializing param=text_model.encoder.layers.4.layer_norm1.bias]
# Loading weights:  34%|███▍      | 67/196 [00:00<00:00, 3493.65it/s, Materializing param=text_model.encoder.layers.4.layer_norm1.bias]
# Loading weights:  35%|███▍      | 68/196 [00:00<00:00, 3514.85it/s, Materializing param=text_model.encoder.layers.4.layer_norm1.weight]
# Loading weights:  35%|███▍      | 68/196 [00:00<00:00, 3492.81it/s, Materializing param=text_model.encoder.layers.4.layer_norm1.weight]
# Loading weights:  35%|███▌      | 69/196 [00:00<00:00, 3511.16it/s, Materializing param=text_model.encoder.layers.4.layer_norm2.bias]
# Loading weights:  35%|███▌      | 69/196 [00:00<00:00, 3494.16it/s, Materializing param=text_model.encoder.layers.4.layer_norm2.bias]
# Loading weights:  36%|███▌      | 70/196 [00:00<00:00, 3512.31it/s, Materializing param=text_model.encoder.layers.4.layer_norm2.weight]
# Loading weights:  36%|███▌      | 70/196 [00:00<00:00, 3500.67it/s, Materializing param=text_model.encoder.layers.4.layer_norm2.weight]
# Loading weights:  36%|███▌      | 71/196 [00:00<00:00, 3530.94it/s, Materializing param=text_model.encoder.layers.4.mlp.fc1.bias]
# Loading weights:  36%|███▌      | 71/196 [00:00<00:00, 3521.17it/s, Materializing param=text_model.encoder.layers.4.mlp.fc1.bias]
# Loading weights:  37%|███▋      | 72/196 [00:00<00:00, 3552.86it/s, Materializing param=text_model.encoder.layers.4.mlp.fc1.weight]
# Loading weights:  37%|███▋      | 72/196 [00:00<00:00, 3543.44it/s, Materializing param=text_model.encoder.layers.4.mlp.fc1.weight]
# Loading weights:  37%|███▋      | 73/196 [00:00<00:00, 3565.55it/s, Materializing param=text_model.encoder.layers.4.mlp.fc2.bias]
# Loading weights:  37%|███▋      | 73/196 [00:00<00:00, 3554.16it/s, Materializing param=text_model.encoder.layers.4.mlp.fc2.bias]
# Loading weights:  38%|███▊      | 74/196 [00:00<00:00, 3582.35it/s, Materializing param=text_model.encoder.layers.4.mlp.fc2.weight]
# Loading weights:  38%|███▊      | 74/196 [00:00<00:00, 3573.11it/s, Materializing param=text_model.encoder.layers.4.mlp.fc2.weight]
# Loading weights:  38%|███▊      | 75/196 [00:00<00:00, 3603.77it/s, Materializing param=text_model.encoder.layers.4.self_attn.k_proj.bias]
# Loading weights:  38%|███▊      | 75/196 [00:00<00:00, 3594.46it/s, Materializing param=text_model.encoder.layers.4.self_attn.k_proj.bias]
# Loading weights:  39%|███▉      | 76/196 [00:00<00:00, 3617.50it/s, Materializing param=text_model.encoder.layers.4.self_attn.k_proj.weight]
# Loading weights:  39%|███▉      | 76/196 [00:00<00:00, 3607.11it/s, Materializing param=text_model.encoder.layers.4.self_attn.k_proj.weight]
# Loading weights:  39%|███▉      | 77/196 [00:00<00:00, 3636.26it/s, Materializing param=text_model.encoder.layers.4.self_attn.out_proj.bias]
# Loading weights:  39%|███▉      | 77/196 [00:00<00:00, 3626.50it/s, Materializing param=text_model.encoder.layers.4.self_attn.out_proj.bias]
# Loading weights:  40%|███▉      | 78/196 [00:00<00:00, 3656.52it/s, Materializing param=text_model.encoder.layers.4.self_attn.out_proj.weight]
# Loading weights:  40%|███▉      | 78/196 [00:00<00:00, 3647.26it/s, Materializing param=text_model.encoder.layers.4.self_attn.out_proj.weight]
# Loading weights:  40%|████      | 79/196 [00:00<00:00, 3662.26it/s, Materializing param=text_model.encoder.layers.4.self_attn.q_proj.bias]
# Loading weights:  40%|████      | 79/196 [00:00<00:00, 3652.04it/s, Materializing param=text_model.encoder.layers.4.self_attn.q_proj.bias]
# Loading weights:  41%|████      | 80/196 [00:00<00:00, 3681.07it/s, Materializing param=text_model.encoder.layers.4.self_attn.q_proj.weight]
# Loading weights:  41%|████      | 80/196 [00:00<00:00, 3672.17it/s, Materializing param=text_model.encoder.layers.4.self_attn.q_proj.weight]
# Loading weights:  41%|████▏     | 81/196 [00:00<00:00, 3701.66it/s, Materializing param=text_model.encoder.layers.4.self_attn.v_proj.bias]
# Loading weights:  41%|████▏     | 81/196 [00:00<00:00, 3692.69it/s, Materializing param=text_model.encoder.layers.4.self_attn.v_proj.bias]
# Loading weights:  42%|████▏     | 82/196 [00:00<00:00, 3720.77it/s, Materializing param=text_model.encoder.layers.4.self_attn.v_proj.weight]
# Loading weights:  42%|████▏     | 82/196 [00:00<00:00, 3711.85it/s, Materializing param=text_model.encoder.layers.4.self_attn.v_proj.weight]
# Loading weights:  42%|████▏     | 83/196 [00:00<00:00, 3741.13it/s, Materializing param=text_model.encoder.layers.5.layer_norm1.bias]
# Loading weights:  42%|████▏     | 83/196 [00:00<00:00, 3731.79it/s, Materializing param=text_model.encoder.layers.5.layer_norm1.bias]
# Loading weights:  43%|████▎     | 84/196 [00:00<00:00, 3760.58it/s, Materializing param=text_model.encoder.layers.5.layer_norm1.weight]
# Loading weights:  43%|████▎     | 84/196 [00:00<00:00, 3751.85it/s, Materializing param=text_model.encoder.layers.5.layer_norm1.weight]
# Loading weights:  43%|████▎     | 85/196 [00:00<00:00, 3766.24it/s, Materializing param=text_model.encoder.layers.5.layer_norm2.bias]
# Loading weights:  43%|████▎     | 85/196 [00:00<00:00, 3756.36it/s, Materializing param=text_model.encoder.layers.5.layer_norm2.bias]
# Loading weights:  44%|████▍     | 86/196 [00:00<00:00, 3784.00it/s, Materializing param=text_model.encoder.layers.5.layer_norm2.weight]
# Loading weights:  44%|████▍     | 86/196 [00:00<00:00, 3775.25it/s, Materializing param=text_model.encoder.layers.5.layer_norm2.weight]
# Loading weights:  44%|████▍     | 87/196 [00:00<00:00, 3803.47it/s, Materializing param=text_model.encoder.layers.5.mlp.fc1.bias]
# Loading weights:  44%|████▍     | 87/196 [00:00<00:00, 3794.88it/s, Materializing param=text_model.encoder.layers.5.mlp.fc1.bias]
# Loading weights:  45%|████▍     | 88/196 [00:00<00:00, 3822.96it/s, Materializing param=text_model.encoder.layers.5.mlp.fc1.weight]
# Loading weights:  45%|████▍     | 88/196 [00:00<00:00, 3805.49it/s, Materializing param=text_model.encoder.layers.5.mlp.fc1.weight]
# Loading weights:  45%|████▌     | 89/196 [00:00<00:00, 3820.61it/s, Materializing param=text_model.encoder.layers.5.mlp.fc2.bias]
# Loading weights:  45%|████▌     | 89/196 [00:00<00:00, 3806.59it/s, Materializing param=text_model.encoder.layers.5.mlp.fc2.bias]
# Loading weights:  46%|████▌     | 90/196 [00:00<00:00, 3817.59it/s, Materializing param=text_model.encoder.layers.5.mlp.fc2.weight]
# Loading weights:  46%|████▌     | 90/196 [00:00<00:00, 3802.82it/s, Materializing param=text_model.encoder.layers.5.mlp.fc2.weight]
# Loading weights:  46%|████▋     | 91/196 [00:00<00:00, 3817.62it/s, Materializing param=text_model.encoder.layers.5.self_attn.k_proj.bias]
# Loading weights:  46%|████▋     | 91/196 [00:00<00:00, 3802.37it/s, Materializing param=text_model.encoder.layers.5.self_attn.k_proj.bias]
# Loading weights:  47%|████▋     | 92/196 [00:00<00:00, 3817.57it/s, Materializing param=text_model.encoder.layers.5.self_attn.k_proj.weight]
# Loading weights:  47%|████▋     | 92/196 [00:00<00:00, 3803.08it/s, Materializing param=text_model.encoder.layers.5.self_attn.k_proj.weight]
# Loading weights:  47%|████▋     | 93/196 [00:00<00:00, 3818.38it/s, Materializing param=text_model.encoder.layers.5.self_attn.out_proj.bias]
# Loading weights:  47%|████▋     | 93/196 [00:00<00:00, 3797.67it/s, Materializing param=text_model.encoder.layers.5.self_attn.out_proj.bias]
# Loading weights:  48%|████▊     | 94/196 [00:00<00:00, 3807.92it/s, Materializing param=text_model.encoder.layers.5.self_attn.out_proj.weight]
# Loading weights:  48%|████▊     | 94/196 [00:00<00:00, 3792.79it/s, Materializing param=text_model.encoder.layers.5.self_attn.out_proj.weight]
# Loading weights:  48%|████▊     | 95/196 [00:00<00:00, 3806.67it/s, Materializing param=text_model.encoder.layers.5.self_attn.q_proj.bias]
# Loading weights:  48%|████▊     | 95/196 [00:00<00:00, 3791.20it/s, Materializing param=text_model.encoder.layers.5.self_attn.q_proj.bias]
# Loading weights:  49%|████▉     | 96/196 [00:00<00:00, 3807.88it/s, Materializing param=text_model.encoder.layers.5.self_attn.q_proj.weight]
# Loading weights:  49%|████▉     | 96/196 [00:00<00:00, 3794.75it/s, Materializing param=text_model.encoder.layers.5.self_attn.q_proj.weight]
# Loading weights:  49%|████▉     | 97/196 [00:00<00:00, 3807.15it/s, Materializing param=text_model.encoder.layers.5.self_attn.v_proj.bias]
# Loading weights:  49%|████▉     | 97/196 [00:00<00:00, 3793.77it/s, Materializing param=text_model.encoder.layers.5.self_attn.v_proj.bias]
# Loading weights:  50%|█████     | 98/196 [00:00<00:00, 3810.49it/s, Materializing param=text_model.encoder.layers.5.self_attn.v_proj.weight]
# Loading weights:  50%|█████     | 98/196 [00:00<00:00, 3798.07it/s, Materializing param=text_model.encoder.layers.5.self_attn.v_proj.weight]
# Loading weights:  51%|█████     | 99/196 [00:00<00:00, 3815.91it/s, Materializing param=text_model.encoder.layers.6.layer_norm1.bias]
# Loading weights:  51%|█████     | 99/196 [00:00<00:00, 3803.75it/s, Materializing param=text_model.encoder.layers.6.layer_norm1.bias]
# Loading weights:  51%|█████     | 100/196 [00:00<00:00, 3821.93it/s, Materializing param=text_model.encoder.layers.6.layer_norm1.weight]
# Loading weights:  51%|█████     | 100/196 [00:00<00:00, 3810.06it/s, Materializing param=text_model.encoder.layers.6.layer_norm1.weight]
# Loading weights:  52%|█████▏    | 101/196 [00:00<00:00, 3827.85it/s, Materializing param=text_model.encoder.layers.6.layer_norm2.bias]
# Loading weights:  52%|█████▏    | 101/196 [00:00<00:00, 3811.84it/s, Materializing param=text_model.encoder.layers.6.layer_norm2.bias]
# Loading weights:  52%|█████▏    | 102/196 [00:00<00:00, 3827.84it/s, Materializing param=text_model.encoder.layers.6.layer_norm2.weight]
# Loading weights:  52%|█████▏    | 102/196 [00:00<00:00, 3816.00it/s, Materializing param=text_model.encoder.layers.6.layer_norm2.weight]
# Loading weights:  53%|█████▎    | 103/196 [00:00<00:00, 3833.78it/s, Materializing param=text_model.encoder.layers.6.mlp.fc1.bias]
# Loading weights:  53%|█████▎    | 103/196 [00:00<00:00, 3822.21it/s, Materializing param=text_model.encoder.layers.6.mlp.fc1.bias]
# Loading weights:  53%|█████▎    | 104/196 [00:00<00:00, 3839.62it/s, Materializing param=text_model.encoder.layers.6.mlp.fc1.weight]
# Loading weights:  53%|█████▎    | 104/196 [00:00<00:00, 3825.88it/s, Materializing param=text_model.encoder.layers.6.mlp.fc1.weight]
# Loading weights:  54%|█████▎    | 105/196 [00:00<00:00, 3840.77it/s, Materializing param=text_model.encoder.layers.6.mlp.fc2.bias]
# Loading weights:  54%|█████▎    | 105/196 [00:00<00:00, 3825.69it/s, Materializing param=text_model.encoder.layers.6.mlp.fc2.bias]
# Loading weights:  54%|█████▍    | 106/196 [00:00<00:00, 3839.05it/s, Materializing param=text_model.encoder.layers.6.mlp.fc2.weight]
# Loading weights:  54%|█████▍    | 106/196 [00:00<00:00, 3827.55it/s, Materializing param=text_model.encoder.layers.6.mlp.fc2.weight]
# Loading weights:  55%|█████▍    | 107/196 [00:00<00:00, 3843.80it/s, Materializing param=text_model.encoder.layers.6.self_attn.k_proj.bias]
# Loading weights:  55%|█████▍    | 107/196 [00:00<00:00, 3826.69it/s, Materializing param=text_model.encoder.layers.6.self_attn.k_proj.bias]
# Loading weights:  55%|█████▌    | 108/196 [00:00<00:00, 3839.28it/s, Materializing param=text_model.encoder.layers.6.self_attn.k_proj.weight]
# Loading weights:  55%|█████▌    | 108/196 [00:00<00:00, 3827.86it/s, Materializing param=text_model.encoder.layers.6.self_attn.k_proj.weight]
# Loading weights:  56%|█████▌    | 109/196 [00:00<00:00, 3842.20it/s, Materializing param=text_model.encoder.layers.6.self_attn.out_proj.bias]
# Loading weights:  56%|█████▌    | 109/196 [00:00<00:00, 3827.08it/s, Materializing param=text_model.encoder.layers.6.self_attn.out_proj.bias]
# Loading weights:  56%|█████▌    | 110/196 [00:00<00:00, 3840.97it/s, Materializing param=text_model.encoder.layers.6.self_attn.out_proj.weight]
# Loading weights:  56%|█████▌    | 110/196 [00:00<00:00, 3828.70it/s, Materializing param=text_model.encoder.layers.6.self_attn.out_proj.weight]
# Loading weights:  57%|█████▋    | 111/196 [00:00<00:00, 3839.96it/s, Materializing param=text_model.encoder.layers.6.self_attn.q_proj.bias]
# Loading weights:  57%|█████▋    | 111/196 [00:00<00:00, 3828.15it/s, Materializing param=text_model.encoder.layers.6.self_attn.q_proj.bias]
# Loading weights:  57%|█████▋    | 112/196 [00:00<00:00, 3841.60it/s, Materializing param=text_model.encoder.layers.6.self_attn.q_proj.weight]
# Loading weights:  57%|█████▋    | 112/196 [00:00<00:00, 3830.20it/s, Materializing param=text_model.encoder.layers.6.self_attn.q_proj.weight]
# Loading weights:  58%|█████▊    | 113/196 [00:00<00:00, 3837.39it/s, Materializing param=text_model.encoder.layers.6.self_attn.v_proj.bias]
# Loading weights:  58%|█████▊    | 113/196 [00:00<00:00, 3822.35it/s, Materializing param=text_model.encoder.layers.6.self_attn.v_proj.bias]
# Loading weights:  58%|█████▊    | 114/196 [00:00<00:00, 3832.35it/s, Materializing param=text_model.encoder.layers.6.self_attn.v_proj.weight]
# Loading weights:  58%|█████▊    | 114/196 [00:00<00:00, 3820.83it/s, Materializing param=text_model.encoder.layers.6.self_attn.v_proj.weight]
# Loading weights:  59%|█████▊    | 115/196 [00:00<00:00, 3833.67it/s, Materializing param=text_model.encoder.layers.7.layer_norm1.bias]
# Loading weights:  59%|█████▊    | 115/196 [00:00<00:00, 3821.76it/s, Materializing param=text_model.encoder.layers.7.layer_norm1.bias]
# Loading weights:  59%|█████▉    | 116/196 [00:00<00:00, 3833.92it/s, Materializing param=text_model.encoder.layers.7.layer_norm1.weight]
# Loading weights:  59%|█████▉    | 116/196 [00:00<00:00, 3822.53it/s, Materializing param=text_model.encoder.layers.7.layer_norm1.weight]
# Loading weights:  60%|█████▉    | 117/196 [00:00<00:00, 3830.95it/s, Materializing param=text_model.encoder.layers.7.layer_norm2.bias]
# Loading weights:  60%|█████▉    | 117/196 [00:00<00:00, 3817.45it/s, Materializing param=text_model.encoder.layers.7.layer_norm2.bias]
# Loading weights:  60%|██████    | 118/196 [00:00<00:00, 3827.63it/s, Materializing param=text_model.encoder.layers.7.layer_norm2.weight]
# Loading weights:  60%|██████    | 118/196 [00:00<00:00, 3816.97it/s, Materializing param=text_model.encoder.layers.7.layer_norm2.weight]
# Loading weights:  61%|██████    | 119/196 [00:00<00:00, 3830.68it/s, Materializing param=text_model.encoder.layers.7.mlp.fc1.bias]
# Loading weights:  61%|██████    | 119/196 [00:00<00:00, 3820.24it/s, Materializing param=text_model.encoder.layers.7.mlp.fc1.bias]
# Loading weights:  61%|██████    | 120/196 [00:00<00:00, 3831.32it/s, Materializing param=text_model.encoder.layers.7.mlp.fc1.weight]
# Loading weights:  61%|██████    | 120/196 [00:00<00:00, 3818.04it/s, Materializing param=text_model.encoder.layers.7.mlp.fc1.weight]
# Loading weights:  62%|██████▏   | 121/196 [00:00<00:00, 3827.18it/s, Materializing param=text_model.encoder.layers.7.mlp.fc2.bias]
# Loading weights:  62%|██████▏   | 121/196 [00:00<00:00, 3815.84it/s, Materializing param=text_model.encoder.layers.7.mlp.fc2.bias]
# Loading weights:  62%|██████▏   | 122/196 [00:00<00:00, 3823.00it/s, Materializing param=text_model.encoder.layers.7.mlp.fc2.weight]
# Loading weights:  62%|██████▏   | 122/196 [00:00<00:00, 3812.58it/s, Materializing param=text_model.encoder.layers.7.mlp.fc2.weight]
# Loading weights:  63%|██████▎   | 123/196 [00:00<00:00, 3825.30it/s, Materializing param=text_model.encoder.layers.7.self_attn.k_proj.bias]
# Loading weights:  63%|██████▎   | 123/196 [00:00<00:00, 3814.86it/s, Materializing param=text_model.encoder.layers.7.self_attn.k_proj.bias]
# Loading weights:  63%|██████▎   | 124/196 [00:00<00:00, 3818.94it/s, Materializing param=text_model.encoder.layers.7.self_attn.k_proj.weight]
# Loading weights:  63%|██████▎   | 124/196 [00:00<00:00, 3805.97it/s, Materializing param=text_model.encoder.layers.7.self_attn.k_proj.weight]
# Loading weights:  64%|██████▍   | 125/196 [00:00<00:00, 3814.75it/s, Materializing param=text_model.encoder.layers.7.self_attn.out_proj.bias]
# Loading weights:  64%|██████▍   | 125/196 [00:00<00:00, 3804.23it/s, Materializing param=text_model.encoder.layers.7.self_attn.out_proj.bias]
# Loading weights:  64%|██████▍   | 126/196 [00:00<00:00, 3816.58it/s, Materializing param=text_model.encoder.layers.7.self_attn.out_proj.weight]
# Loading weights:  64%|██████▍   | 126/196 [00:00<00:00, 3806.44it/s, Materializing param=text_model.encoder.layers.7.self_attn.out_proj.weight]
# Loading weights:  65%|██████▍   | 127/196 [00:00<00:00, 3818.01it/s, Materializing param=text_model.encoder.layers.7.self_attn.q_proj.bias]
# Loading weights:  65%|██████▍   | 127/196 [00:00<00:00, 3807.85it/s, Materializing param=text_model.encoder.layers.7.self_attn.q_proj.bias]
# Loading weights:  65%|██████▌   | 128/196 [00:00<00:00, 3815.36it/s, Materializing param=text_model.encoder.layers.7.self_attn.q_proj.weight]
# Loading weights:  65%|██████▌   | 128/196 [00:00<00:00, 3804.65it/s, Materializing param=text_model.encoder.layers.7.self_attn.q_proj.weight]
# Loading weights:  66%|██████▌   | 129/196 [00:00<00:00, 3812.20it/s, Materializing param=text_model.encoder.layers.7.self_attn.v_proj.bias]
# Loading weights:  66%|██████▌   | 129/196 [00:00<00:00, 3801.78it/s, Materializing param=text_model.encoder.layers.7.self_attn.v_proj.bias]
# Loading weights:  66%|██████▋   | 130/196 [00:00<00:00, 3813.67it/s, Materializing param=text_model.encoder.layers.7.self_attn.v_proj.weight]
# Loading weights:  66%|██████▋   | 130/196 [00:00<00:00, 3804.04it/s, Materializing param=text_model.encoder.layers.7.self_attn.v_proj.weight]
# Loading weights:  67%|██████▋   | 131/196 [00:00<00:00, 3809.41it/s, Materializing param=text_model.encoder.layers.8.layer_norm1.bias]
# Loading weights:  67%|██████▋   | 131/196 [00:00<00:00, 3795.07it/s, Materializing param=text_model.encoder.layers.8.layer_norm1.bias]
# Loading weights:  67%|██████▋   | 132/196 [00:00<00:00, 3804.96it/s, Materializing param=text_model.encoder.layers.8.layer_norm1.weight]
# Loading weights:  67%|██████▋   | 132/196 [00:00<00:00, 3795.28it/s, Materializing param=text_model.encoder.layers.8.layer_norm1.weight]
# Loading weights:  68%|██████▊   | 133/196 [00:00<00:00, 3803.98it/s, Materializing param=text_model.encoder.layers.8.layer_norm2.bias]
# Loading weights:  68%|██████▊   | 133/196 [00:00<00:00, 3792.63it/s, Materializing param=text_model.encoder.layers.8.layer_norm2.bias]
# Loading weights:  68%|██████▊   | 134/196 [00:00<00:00, 3802.45it/s, Materializing param=text_model.encoder.layers.8.layer_norm2.weight]
# Loading weights:  68%|██████▊   | 134/196 [00:00<00:00, 3792.24it/s, Materializing param=text_model.encoder.layers.8.layer_norm2.weight]
# Loading weights:  69%|██████▉   | 135/196 [00:00<00:00, 3797.07it/s, Materializing param=text_model.encoder.layers.8.mlp.fc1.bias]
# Loading weights:  69%|██████▉   | 135/196 [00:00<00:00, 3786.43it/s, Materializing param=text_model.encoder.layers.8.mlp.fc1.bias]
# Loading weights:  69%|██████▉   | 136/196 [00:00<00:00, 3797.09it/s, Materializing param=text_model.encoder.layers.8.mlp.fc1.weight]
# Loading weights:  69%|██████▉   | 136/196 [00:00<00:00, 3787.18it/s, Materializing param=text_model.encoder.layers.8.mlp.fc1.weight]
# Loading weights:  70%|██████▉   | 137/196 [00:00<00:00, 3798.79it/s, Materializing param=text_model.encoder.layers.8.mlp.fc2.bias]
# Loading weights:  70%|██████▉   | 137/196 [00:00<00:00, 3788.99it/s, Materializing param=text_model.encoder.layers.8.mlp.fc2.bias]
# Loading weights:  70%|███████   | 138/196 [00:00<00:00, 3800.29it/s, Materializing param=text_model.encoder.layers.8.mlp.fc2.weight]
# Loading weights:  70%|███████   | 138/196 [00:00<00:00, 3788.97it/s, Materializing param=text_model.encoder.layers.8.mlp.fc2.weight]
# Loading weights:  71%|███████   | 139/196 [00:00<00:00, 3797.68it/s, Materializing param=text_model.encoder.layers.8.self_attn.k_proj.bias]
# Loading weights:  71%|███████   | 139/196 [00:00<00:00, 3787.64it/s, Materializing param=text_model.encoder.layers.8.self_attn.k_proj.bias]
# Loading weights:  71%|███████▏  | 140/196 [00:00<00:00, 3798.67it/s, Materializing param=text_model.encoder.layers.8.self_attn.k_proj.weight]
# Loading weights:  71%|███████▏  | 140/196 [00:00<00:00, 3788.94it/s, Materializing param=text_model.encoder.layers.8.self_attn.k_proj.weight]
# Loading weights:  72%|███████▏  | 141/196 [00:00<00:00, 3800.26it/s, Materializing param=text_model.encoder.layers.8.self_attn.out_proj.bias]
# Loading weights:  72%|███████▏  | 141/196 [00:00<00:00, 3790.74it/s, Materializing param=text_model.encoder.layers.8.self_attn.out_proj.bias]
# Loading weights:  72%|███████▏  | 142/196 [00:00<00:00, 3801.47it/s, Materializing param=text_model.encoder.layers.8.self_attn.out_proj.weight]
# Loading weights:  72%|███████▏  | 142/196 [00:00<00:00, 3788.65it/s, Materializing param=text_model.encoder.layers.8.self_attn.out_proj.weight]
# Loading weights:  73%|███████▎  | 143/196 [00:00<00:00, 3797.70it/s, Materializing param=text_model.encoder.layers.8.self_attn.q_proj.bias]
# Loading weights:  73%|███████▎  | 143/196 [00:00<00:00, 3788.15it/s, Materializing param=text_model.encoder.layers.8.self_attn.q_proj.bias]
# Loading weights:  73%|███████▎  | 144/196 [00:00<00:00, 3798.93it/s, Materializing param=text_model.encoder.layers.8.self_attn.q_proj.weight]
# Loading weights:  73%|███████▎  | 144/196 [00:00<00:00, 3789.46it/s, Materializing param=text_model.encoder.layers.8.self_attn.q_proj.weight]
# Loading weights:  74%|███████▍  | 145/196 [00:00<00:00, 3800.35it/s, Materializing param=text_model.encoder.layers.8.self_attn.v_proj.bias]
# Loading weights:  74%|███████▍  | 145/196 [00:00<00:00, 3791.18it/s, Materializing param=text_model.encoder.layers.8.self_attn.v_proj.bias]
# Loading weights:  74%|███████▍  | 146/196 [00:00<00:00, 3801.83it/s, Materializing param=text_model.encoder.layers.8.self_attn.v_proj.weight]
# Loading weights:  74%|███████▍  | 146/196 [00:00<00:00, 3789.15it/s, Materializing param=text_model.encoder.layers.8.self_attn.v_proj.weight]
# Loading weights:  75%|███████▌  | 147/196 [00:00<00:00, 3798.65it/s, Materializing param=text_model.encoder.layers.9.layer_norm1.bias]
# Loading weights:  75%|███████▌  | 147/196 [00:00<00:00, 3789.57it/s, Materializing param=text_model.encoder.layers.9.layer_norm1.bias]
# Loading weights:  76%|███████▌  | 148/196 [00:00<00:00, 3799.72it/s, Materializing param=text_model.encoder.layers.9.layer_norm1.weight]
# Loading weights:  76%|███████▌  | 148/196 [00:00<00:00, 3790.72it/s, Materializing param=text_model.encoder.layers.9.layer_norm1.weight]
# Loading weights:  76%|███████▌  | 149/196 [00:00<00:00, 3801.89it/s, Materializing param=text_model.encoder.layers.9.layer_norm2.bias]
# Loading weights:  76%|███████▌  | 149/196 [00:00<00:00, 3793.01it/s, Materializing param=text_model.encoder.layers.9.layer_norm2.bias]
# Loading weights:  77%|███████▋  | 150/196 [00:00<00:00, 3802.01it/s, Materializing param=text_model.encoder.layers.9.layer_norm2.weight]
# Loading weights:  77%|███████▋  | 150/196 [00:00<00:00, 3792.23it/s, Materializing param=text_model.encoder.layers.9.layer_norm2.weight]
# Loading weights:  77%|███████▋  | 151/196 [00:00<00:00, 3802.59it/s, Materializing param=text_model.encoder.layers.9.mlp.fc1.bias]
# Loading weights:  77%|███████▋  | 151/196 [00:00<00:00, 3793.93it/s, Materializing param=text_model.encoder.layers.9.mlp.fc1.bias]
# Loading weights:  78%|███████▊  | 152/196 [00:00<00:00, 3804.68it/s, Materializing param=text_model.encoder.layers.9.mlp.fc1.weight]
# Loading weights:  78%|███████▊  | 152/196 [00:00<00:00, 3796.07it/s, Materializing param=text_model.encoder.layers.9.mlp.fc1.weight]
# Loading weights:  78%|███████▊  | 153/196 [00:00<00:00, 3806.83it/s, Materializing param=text_model.encoder.layers.9.mlp.fc2.bias]
# Loading weights:  78%|███████▊  | 153/196 [00:00<00:00, 3798.31it/s, Materializing param=text_model.encoder.layers.9.mlp.fc2.bias]
# Loading weights:  79%|███████▊  | 154/196 [00:00<00:00, 3806.78it/s, Materializing param=text_model.encoder.layers.9.mlp.fc2.weight]
# Loading weights:  79%|███████▊  | 154/196 [00:00<00:00, 3797.22it/s, Materializing param=text_model.encoder.layers.9.mlp.fc2.weight]
# Loading weights:  79%|███████▉  | 155/196 [00:00<00:00, 3806.95it/s, Materializing param=text_model.encoder.layers.9.self_attn.k_proj.bias]
# Loading weights:  79%|███████▉  | 155/196 [00:00<00:00, 3798.28it/s, Materializing param=text_model.encoder.layers.9.self_attn.k_proj.bias]
# Loading weights:  80%|███████▉  | 156/196 [00:00<00:00, 3808.34it/s, Materializing param=text_model.encoder.layers.9.self_attn.k_proj.weight]
# Loading weights:  80%|███████▉  | 156/196 [00:00<00:00, 3799.76it/s, Materializing param=text_model.encoder.layers.9.self_attn.k_proj.weight]
# Loading weights:  80%|████████  | 157/196 [00:00<00:00, 3809.94it/s, Materializing param=text_model.encoder.layers.9.self_attn.out_proj.bias]
# Loading weights:  80%|████████  | 157/196 [00:00<00:00, 3801.34it/s, Materializing param=text_model.encoder.layers.9.self_attn.out_proj.bias]
# Loading weights:  81%|████████  | 158/196 [00:00<00:00, 3808.56it/s, Materializing param=text_model.encoder.layers.9.self_attn.out_proj.weight]
# Loading weights:  81%|████████  | 158/196 [00:00<00:00, 3799.71it/s, Materializing param=text_model.encoder.layers.9.self_attn.out_proj.weight]
# Loading weights:  81%|████████  | 159/196 [00:00<00:00, 3809.19it/s, Materializing param=text_model.encoder.layers.9.self_attn.q_proj.bias]
# Loading weights:  81%|████████  | 159/196 [00:00<00:00, 3800.77it/s, Materializing param=text_model.encoder.layers.9.self_attn.q_proj.bias]
# Loading weights:  82%|████████▏ | 160/196 [00:00<00:00, 3810.69it/s, Materializing param=text_model.encoder.layers.9.self_attn.q_proj.weight]
# Loading weights:  82%|████████▏ | 160/196 [00:00<00:00, 3802.35it/s, Materializing param=text_model.encoder.layers.9.self_attn.q_proj.weight]
# Loading weights:  82%|████████▏ | 161/196 [00:00<00:00, 3811.58it/s, Materializing param=text_model.encoder.layers.9.self_attn.v_proj.bias]
# Loading weights:  82%|████████▏ | 161/196 [00:00<00:00, 3803.10it/s, Materializing param=text_model.encoder.layers.9.self_attn.v_proj.bias]
# Loading weights:  83%|████████▎ | 162/196 [00:00<00:00, 3809.88it/s, Materializing param=text_model.encoder.layers.9.self_attn.v_proj.weight]
# Loading weights:  83%|████████▎ | 162/196 [00:00<00:00, 3801.23it/s, Materializing param=text_model.encoder.layers.9.self_attn.v_proj.weight]
# Loading weights:  83%|████████▎ | 163/196 [00:00<00:00, 3810.88it/s, Materializing param=text_model.encoder.layers.10.layer_norm1.bias]
# Loading weights:  83%|████████▎ | 163/196 [00:00<00:00, 3802.76it/s, Materializing param=text_model.encoder.layers.10.layer_norm1.bias]
# Loading weights:  84%|████████▎ | 164/196 [00:00<00:00, 3812.83it/s, Materializing param=text_model.encoder.layers.10.layer_norm1.weight]
# Loading weights:  84%|████████▎ | 164/196 [00:00<00:00, 3804.82it/s, Materializing param=text_model.encoder.layers.10.layer_norm1.weight]
# Loading weights:  84%|████████▍ | 165/196 [00:00<00:00, 3814.71it/s, Materializing param=text_model.encoder.layers.10.layer_norm2.bias]
# Loading weights:  84%|████████▍ | 165/196 [00:00<00:00, 3806.59it/s, Materializing param=text_model.encoder.layers.10.layer_norm2.bias]
# Loading weights:  85%|████████▍ | 166/196 [00:00<00:00, 3813.65it/s, Materializing param=text_model.encoder.layers.10.layer_norm2.weight]
# Loading weights:  85%|████████▍ | 166/196 [00:00<00:00, 3805.31it/s, Materializing param=text_model.encoder.layers.10.layer_norm2.weight]
# Loading weights:  85%|████████▌ | 167/196 [00:00<00:00, 3815.08it/s, Materializing param=text_model.encoder.layers.10.mlp.fc1.bias]
# Loading weights:  85%|████████▌ | 167/196 [00:00<00:00, 3807.26it/s, Materializing param=text_model.encoder.layers.10.mlp.fc1.bias]
# Loading weights:  86%|████████▌ | 168/196 [00:00<00:00, 3816.99it/s, Materializing param=text_model.encoder.layers.10.mlp.fc1.weight]
# Loading weights:  86%|████████▌ | 168/196 [00:00<00:00, 3809.17it/s, Materializing param=text_model.encoder.layers.10.mlp.fc1.weight]
# Loading weights:  86%|████████▌ | 169/196 [00:00<00:00, 3818.76it/s, Materializing param=text_model.encoder.layers.10.mlp.fc2.bias]
# Loading weights:  86%|████████▌ | 169/196 [00:00<00:00, 3810.85it/s, Materializing param=text_model.encoder.layers.10.mlp.fc2.bias]
# Loading weights:  87%|████████▋ | 170/196 [00:00<00:00, 3817.88it/s, Materializing param=text_model.encoder.layers.10.mlp.fc2.weight]
# Loading weights:  87%|████████▋ | 170/196 [00:00<00:00, 3809.78it/s, Materializing param=text_model.encoder.layers.10.mlp.fc2.weight]
# ...
# Loading weights:  90%|█████████ | 467/517 [00:00<00:00, 3735.68it/s, Materializing param=text_model.encoder.layers.29.layer_norm1.bias]
# Loading weights:  91%|█████████ | 468/517 [00:00<00:00, 3735.68it/s, Materializing param=text_model.encoder.layers.29.layer_norm1.weight]
# Loading weights:  91%|█████████ | 468/517 [00:00<00:00, 3735.68it/s, Materializing param=text_model.encoder.layers.29.layer_norm1.weight]
# Loading weights:  91%|█████████ | 469/517 [00:00<00:00, 3735.68it/s, Materializing param=text_model.encoder.layers.29.layer_norm2.bias]
# Loading weights:  91%|█████████ | 469/517 [00:00<00:00, 3735.68it/s, Materializing param=text_model.encoder.layers.29.layer_norm2.bias]
# Loading weights:  91%|█████████ | 470/517 [00:00<00:00, 3735.68it/s, Materializing param=text_model.encoder.layers.29.layer_norm2.weight]
# Loading weights:  91%|█████████ | 470/517 [00:00<00:00, 3735.68it/s, Materializing param=text_model.encoder.layers.29.layer_norm2.weight]
# Loading weights:  91%|█████████ | 471/517 [00:00<00:00, 3735.68it/s, Materializing param=text_model.encoder.layers.29.mlp.fc1.bias]
# Loading weights:  91%|█████████ | 471/517 [00:00<00:00, 3735.68it/s, Materializing param=text_model.encoder.layers.29.mlp.fc1.bias]
# Loading weights:  91%|█████████▏| 472/517 [00:00<00:00, 3735.68it/s, Materializing param=text_model.encoder.layers.29.mlp.fc1.weight]
# Loading weights:  91%|█████████▏| 472/517 [00:00<00:00, 3735.68it/s, Materializing param=text_model.encoder.layers.29.mlp.fc1.weight]
# Loading weights:  91%|█████████▏| 473/517 [00:00<00:00, 3735.68it/s, Materializing param=text_model.encoder.layers.29.mlp.fc2.bias]
# Loading weights:  91%|█████████▏| 473/517 [00:00<00:00, 3735.68it/s, Materializing param=text_model.encoder.layers.29.mlp.fc2.bias]
# Loading weights:  92%|█████████▏| 474/517 [00:00<00:00, 3735.68it/s, Materializing param=text_model.encoder.layers.29.mlp.fc2.weight]
# Loading weights:  92%|█████████▏| 474/517 [00:00<00:00, 3735.68it/s, Materializing param=text_model.encoder.layers.29.mlp.fc2.weight]
# Loading weights:  92%|█████████▏| 475/517 [00:00<00:00, 3735.68it/s, Materializing param=text_model.encoder.layers.29.self_attn.k_proj.bias]
# Loading weights:  92%|█████████▏| 475/517 [00:00<00:00, 3735.68it/s, Materializing param=text_model.encoder.layers.29.self_attn.k_proj.bias]
# Loading weights:  92%|█████████▏| 476/517 [00:00<00:00, 3735.68it/s, Materializing param=text_model.encoder.layers.29.self_attn.k_proj.weight]
# Loading weights:  92%|█████████▏| 476/517 [00:00<00:00, 3735.68it/s, Materializing param=text_model.encoder.layers.29.self_attn.k_proj.weight]
# Loading weights:  92%|█████████▏| 477/517 [00:00<00:00, 3735.68it/s, Materializing param=text_model.encoder.layers.29.self_attn.out_proj.bias]
# Loading weights:  92%|█████████▏| 477/517 [00:00<00:00, 3735.68it/s, Materializing param=text_model.encoder.layers.29.self_attn.out_proj.bias]
# Loading weights:  92%|█████████▏| 478/517 [00:00<00:00, 3735.68it/s, Materializing param=text_model.encoder.layers.29.self_attn.out_proj.weight]
# Loading weights:  92%|█████████▏| 478/517 [00:00<00:00, 3735.68it/s, Materializing param=text_model.encoder.layers.29.self_attn.out_proj.weight]
# Loading weights:  93%|█████████▎| 479/517 [00:00<00:00, 3735.68it/s, Materializing param=text_model.encoder.layers.29.self_attn.q_proj.bias]
# Loading weights:  93%|█████████▎| 479/517 [00:00<00:00, 3735.68it/s, Materializing param=text_model.encoder.layers.29.self_attn.q_proj.bias]
# Loading weights:  93%|█████████▎| 480/517 [00:00<00:00, 3735.68it/s, Materializing param=text_model.encoder.layers.29.self_attn.q_proj.weight]
# Loading weights:  93%|█████████▎| 480/517 [00:00<00:00, 3735.68it/s, Materializing param=text_model.encoder.layers.29.self_attn.q_proj.weight]
# Loading weights:  93%|█████████▎| 481/517 [00:00<00:00, 3735.68it/s, Materializing param=text_model.encoder.layers.29.self_attn.v_proj.bias]
# Loading weights:  93%|█████████▎| 481/517 [00:00<00:00, 3735.68it/s, Materializing param=text_model.encoder.layers.29.self_attn.v_proj.bias]
# Loading weights:  93%|█████████▎| 482/517 [00:00<00:00, 3735.68it/s, Materializing param=text_model.encoder.layers.29.self_attn.v_proj.weight]
# Loading weights:  93%|█████████▎| 482/517 [00:00<00:00, 3735.68it/s, Materializing param=text_model.encoder.layers.29.self_attn.v_proj.weight]
# Loading weights:  93%|█████████▎| 483/517 [00:00<00:00, 3735.68it/s, Materializing param=text_model.encoder.layers.30.layer_norm1.bias]
# Loading weights:  93%|█████████▎| 483/517 [00:00<00:00, 3735.68it/s, Materializing param=text_model.encoder.layers.30.layer_norm1.bias]
# Loading weights:  94%|█████████▎| 484/517 [00:00<00:00, 3735.68it/s, Materializing param=text_model.encoder.layers.30.layer_norm1.weight]
# Loading weights:  94%|█████████▎| 484/517 [00:00<00:00, 3735.68it/s, Materializing param=text_model.encoder.layers.30.layer_norm1.weight]
# Loading weights:  94%|█████████▍| 485/517 [00:00<00:00, 3735.68it/s, Materializing param=text_model.encoder.layers.30.layer_norm2.bias]
# Loading weights:  94%|█████████▍| 485/517 [00:00<00:00, 3735.68it/s, Materializing param=text_model.encoder.layers.30.layer_norm2.bias]
# Loading weights:  94%|█████████▍| 486/517 [00:00<00:00, 3735.68it/s, Materializing param=text_model.encoder.layers.30.layer_norm2.weight]
# Loading weights:  94%|█████████▍| 486/517 [00:00<00:00, 3735.68it/s, Materializing param=text_model.encoder.layers.30.layer_norm2.weight]
# Loading weights:  94%|█████████▍| 487/517 [00:00<00:00, 3735.68it/s, Materializing param=text_model.encoder.layers.30.mlp.fc1.bias]
# Loading weights:  94%|█████████▍| 487/517 [00:00<00:00, 3735.68it/s, Materializing param=text_model.encoder.layers.30.mlp.fc1.bias]
# Loading weights:  94%|█████████▍| 488/517 [00:00<00:00, 3735.68it/s, Materializing param=text_model.encoder.layers.30.mlp.fc1.weight]
# Loading weights:  94%|█████████▍| 488/517 [00:00<00:00, 3735.68it/s, Materializing param=text_model.encoder.layers.30.mlp.fc1.weight]
# Loading weights:  95%|█████████▍| 489/517 [00:00<00:00, 3735.68it/s, Materializing param=text_model.encoder.layers.30.mlp.fc2.bias]
# Loading weights:  95%|█████████▍| 489/517 [00:00<00:00, 3735.68it/s, Materializing param=text_model.encoder.layers.30.mlp.fc2.bias]
# Loading weights:  95%|█████████▍| 490/517 [00:00<00:00, 3735.68it/s, Materializing param=text_model.encoder.layers.30.mlp.fc2.weight]
# Loading weights:  95%|█████████▍| 490/517 [00:00<00:00, 3735.68it/s, Materializing param=text_model.encoder.layers.30.mlp.fc2.weight]
# Loading weights:  95%|█████████▍| 491/517 [00:00<00:00, 3735.68it/s, Materializing param=text_model.encoder.layers.30.self_attn.k_proj.bias]
# Loading weights:  95%|█████████▍| 491/517 [00:00<00:00, 3735.68it/s, Materializing param=text_model.encoder.layers.30.self_attn.k_proj.bias]
# Loading weights:  95%|█████████▌| 492/517 [00:00<00:00, 3735.68it/s, Materializing param=text_model.encoder.layers.30.self_attn.k_proj.weight]
# Loading weights:  95%|█████████▌| 492/517 [00:00<00:00, 3735.68it/s, Materializing param=text_model.encoder.layers.30.self_attn.k_proj.weight]
# Loading weights:  95%|█████████▌| 493/517 [00:00<00:00, 3735.68it/s, Materializing param=text_model.encoder.layers.30.self_attn.out_proj.bias]
# Loading weights:  95%|█████████▌| 493/517 [00:00<00:00, 3735.68it/s, Materializing param=text_model.encoder.layers.30.self_attn.out_proj.bias]
# Loading weights:  96%|█████████▌| 494/517 [00:00<00:00, 3735.68it/s, Materializing param=text_model.encoder.layers.30.self_attn.out_proj.weight]
# Loading weights:  96%|█████████▌| 494/517 [00:00<00:00, 3735.68it/s, Materializing param=text_model.encoder.layers.30.self_attn.out_proj.weight]
# Loading weights:  96%|█████████▌| 495/517 [00:00<00:00, 3735.68it/s, Materializing param=text_model.encoder.layers.30.self_attn.q_proj.bias]
# Loading weights:  96%|█████████▌| 495/517 [00:00<00:00, 3735.68it/s, Materializing param=text_model.encoder.layers.30.self_attn.q_proj.bias]
# Loading weights:  96%|█████████▌| 496/517 [00:00<00:00, 3735.68it/s, Materializing param=text_model.encoder.layers.30.self_attn.q_proj.weight]
# Loading weights:  96%|█████████▌| 496/517 [00:00<00:00, 3735.68it/s, Materializing param=text_model.encoder.layers.30.self_attn.q_proj.weight]
# Loading weights:  96%|█████████▌| 497/517 [00:00<00:00, 3735.68it/s, Materializing param=text_model.encoder.layers.30.self_attn.v_proj.bias]
# Loading weights:  96%|█████████▌| 497/517 [00:00<00:00, 3735.68it/s, Materializing param=text_model.encoder.layers.30.self_attn.v_proj.bias]
# Loading weights:  96%|█████████▋| 498/517 [00:00<00:00, 3735.68it/s, Materializing param=text_model.encoder.layers.30.self_attn.v_proj.weight]
# Loading weights:  96%|█████████▋| 498/517 [00:00<00:00, 3735.68it/s, Materializing param=text_model.encoder.layers.30.self_attn.v_proj.weight]
# Loading weights:  97%|█████████▋| 499/517 [00:00<00:00, 3735.68it/s, Materializing param=text_model.encoder.layers.31.layer_norm1.bias]
# Loading weights:  97%|█████████▋| 499/517 [00:00<00:00, 3735.68it/s, Materializing param=text_model.encoder.layers.31.layer_norm1.bias]
# Loading weights:  97%|█████████▋| 500/517 [00:00<00:00, 3735.68it/s, Materializing param=text_model.encoder.layers.31.layer_norm1.weight]
# Loading weights:  97%|█████████▋| 500/517 [00:00<00:00, 3735.68it/s, Materializing param=text_model.encoder.layers.31.layer_norm1.weight]
# Loading weights:  97%|█████████▋| 501/517 [00:00<00:00, 3735.68it/s, Materializing param=text_model.encoder.layers.31.layer_norm2.bias]
# Loading weights:  97%|█████████▋| 501/517 [00:00<00:00, 3735.68it/s, Materializing param=text_model.encoder.layers.31.layer_norm2.bias]
# Loading weights:  97%|█████████▋| 502/517 [00:00<00:00, 3735.68it/s, Materializing param=text_model.encoder.layers.31.layer_norm2.weight]
# Loading weights:  97%|█████████▋| 502/517 [00:00<00:00, 3735.68it/s, Materializing param=text_model.encoder.layers.31.layer_norm2.weight]
# Loading weights:  97%|█████████▋| 503/517 [00:00<00:00, 3735.68it/s, Materializing param=text_model.encoder.layers.31.mlp.fc1.bias]
# Loading weights:  97%|█████████▋| 503/517 [00:00<00:00, 3735.68it/s, Materializing param=text_model.encoder.layers.31.mlp.fc1.bias]
# Loading weights:  97%|█████████▋| 504/517 [00:00<00:00, 3735.68it/s, Materializing param=text_model.encoder.layers.31.mlp.fc1.weight]
# Loading weights:  97%|█████████▋| 504/517 [00:00<00:00, 3735.68it/s, Materializing param=text_model.encoder.layers.31.mlp.fc1.weight]
# Loading weights:  98%|█████████▊| 505/517 [00:00<00:00, 3735.68it/s, Materializing param=text_model.encoder.layers.31.mlp.fc2.bias]
# Loading weights:  98%|█████████▊| 505/517 [00:00<00:00, 3735.68it/s, Materializing param=text_model.encoder.layers.31.mlp.fc2.bias]
# Loading weights:  98%|█████████▊| 506/517 [00:00<00:00, 3735.68it/s, Materializing param=text_model.encoder.layers.31.mlp.fc2.weight]
# Loading weights:  98%|█████████▊| 506/517 [00:00<00:00, 3735.68it/s, Materializing param=text_model.encoder.layers.31.mlp.fc2.weight]
# Loading weights:  98%|█████████▊| 507/517 [00:00<00:00, 3735.68it/s, Materializing param=text_model.encoder.layers.31.self_attn.k_proj.bias]
# Loading weights:  98%|█████████▊| 507/517 [00:00<00:00, 3735.68it/s, Materializing param=text_model.encoder.layers.31.self_attn.k_proj.bias]
# Loading weights:  98%|█████████▊| 508/517 [00:00<00:00, 3735.68it/s, Materializing param=text_model.encoder.layers.31.self_attn.k_proj.weight]
# Loading weights:  98%|█████████▊| 508/517 [00:00<00:00, 3735.68it/s, Materializing param=text_model.encoder.layers.31.self_attn.k_proj.weight]
# Loading weights:  98%|█████████▊| 509/517 [00:00<00:00, 3735.68it/s, Materializing param=text_model.encoder.layers.31.self_attn.out_proj.bias]
# Loading weights:  98%|█████████▊| 509/517 [00:00<00:00, 3735.68it/s, Materializing param=text_model.encoder.layers.31.self_attn.out_proj.bias]
# Loading weights:  99%|█████████▊| 510/517 [00:00<00:00, 3735.68it/s, Materializing param=text_model.encoder.layers.31.self_attn.out_proj.weight]
# Loading weights:  99%|█████████▊| 510/517 [00:00<00:00, 3735.68it/s, Materializing param=text_model.encoder.layers.31.self_attn.out_proj.weight]
# Loading weights:  99%|█████████▉| 511/517 [00:00<00:00, 3735.68it/s, Materializing param=text_model.encoder.layers.31.self_attn.q_proj.bias]
# Loading weights:  99%|█████████▉| 511/517 [00:00<00:00, 3735.68it/s, Materializing param=text_model.encoder.layers.31.self_attn.q_proj.bias]
# Loading weights:  99%|█████████▉| 512/517 [00:00<00:00, 3735.68it/s, Materializing param=text_model.encoder.layers.31.self_attn.q_proj.weight]
# Loading weights:  99%|█████████▉| 512/517 [00:00<00:00, 3735.68it/s, Materializing param=text_model.encoder.layers.31.self_attn.q_proj.weight]
# Loading weights:  99%|█████████▉| 513/517 [00:00<00:00, 3735.68it/s, Materializing param=text_model.encoder.layers.31.self_attn.v_proj.bias]
# Loading weights:  99%|█████████▉| 513/517 [00:00<00:00, 3735.68it/s, Materializing param=text_model.encoder.layers.31.self_attn.v_proj.bias]
# Loading weights:  99%|█████████▉| 514/517 [00:00<00:00, 3735.68it/s, Materializing param=text_model.encoder.layers.31.self_attn.v_proj.weight]
# Loading weights:  99%|█████████▉| 514/517 [00:00<00:00, 3735.68it/s, Materializing param=text_model.encoder.layers.31.self_attn.v_proj.weight]
# Loading weights: 100%|█████████▉| 515/517 [00:00<00:00, 3735.68it/s, Materializing param=text_model.final_layer_norm.bias]
# Loading weights: 100%|█████████▉| 515/517 [00:00<00:00, 3735.68it/s, Materializing param=text_model.final_layer_norm.bias]
# Loading weights: 100%|█████████▉| 516/517 [00:00<00:00, 3735.68it/s, Materializing param=text_model.final_layer_norm.weight]
# Loading weights: 100%|█████████▉| 516/517 [00:00<00:00, 3735.68it/s, Materializing param=text_model.final_layer_norm.weight]
# Loading weights: 100%|██████████| 517/517 [00:00<00:00, 3735.68it/s, Materializing param=text_projection.weight]
# Loading weights: 100%|██████████| 517/517 [00:00<00:00, 3691.97it/s, Materializing param=text_projection.weight]
# Loading pipeline components...: 100%|██████████| 7/7 [00:01<00:00,  4.80it/s]
# /usr/local/lib/python3.12/dist-packages/diffusers/pipelines/pipeline_utils.py:2290: FutureWarning: `enable_vae_tiling` is deprecated and will be removed in version 0.40.0. Calling `enable_vae_tiling()` on a `StableDiffusionXLPipeline` is deprecated and this method will be removed in a future version. Please use `pipe.vae.enable_tiling()`.
#   deprecate(
# ERROR:    Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/starlette/routing.py", line 694, in lifespan
#     async with self.lifespan_context(app) as maybe_state:
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/contextlib.py", line 210, in __aenter__
#     return await anext(self.gen)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/content/server.py", line 233, in lifespan
#     pipe.vae.to(torch_device='cuda', torch_dtype=torch.float16)
#   File "/usr/local/lib/python3.12/dist-packages/diffusers/models/modeling_utils.py", line 1451, in to
#     return super().to(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1337, in to
#     device, dtype, non_blocking, convert_to_format = torch._C._nn._parse_to(
#                                                      ^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: to() received an invalid combination of arguments - got (torch_dtype=torch.dtype, torch_device=str, ), but expected one of:
#  * (torch.device device = None, torch.dtype dtype = None, bool non_blocking = False, bool copy = False, *, torch.memory_format memory_format = None)
#  * (torch.dtype dtype, bool non_blocking = False, bool copy = False, *, torch.memory_format memory_format = None)
#  * (Tensor tensor, bool non_blocking = False, bool copy = False, *, torch.memory_format memory_format = None)
#
#
# ERROR:    Application startup failed. Exiting.

# %% [markdown]
# ---
#
# ## Túnel Cloudflared

# %%
import subprocess
import re

# Inicia cloudflared tunnel em background
cloudflared_proc = subprocess.Popen(
    ['cloudflared', 'tunnel', '--url', 'http://localhost:8000'],
    stdout=subprocess.PIPE,
    stderr=subprocess.STDOUT,
)

# Espera a URL do tunnel aparecer nos logs
tunnel_url = None
print('⏳ Esperando URL do tunnel...')
for i in range(30):
    line = cloudflared_proc.stdout.readline().decode('utf-8', errors='replace')
    if not line:
        time.sleep(0.5)
        continue
    print(line.strip())
    match = re.search(r'https://[a-z0-9-]+\.trycloudflare\.com', line)
    if match:
        tunnel_url = match.group(0)
        break

if tunnel_url:
    print()
    print('=' * 60)
    print('🌐 TÚNEL ATIVO!')
    print(f'📎 URL pública: {tunnel_url}')
    print()
    print('Endpoints:')
    print(f'  GET  {tunnel_url}/health')
    print(f'  GET  {tunnel_url}/models')
    print(f'  POST {tunnel_url}/generate')
    print('=' * 60)
    print()
    print('⚠️  TOKEN: ' + SECRET_TOKEN)
    print()
    print('📋 Copie esta URL e cole aqui no chat para eu usar!')
else:
    print('⚠️  Não foi possível obter a URL do tunnel.')
    print('   Verifique: cloudflared_proc.wait()')
# Out:
# ⏳ Esperando URL do tunnel...
# 2026-05-08T23:16:41Z INF Thank you for trying Cloudflare Tunnel. Doing so, without a Cloudflare account, is a quick way to experiment and try it out. However, be aware that these account-less Tunnels have no uptime guarantee, are subject to the Cloudflare Online Services Terms of Use (https://www.cloudflare.com/website-terms/), and Cloudflare reserves the right to investigate your use of Tunnels for violations of such terms. If you intend to use Tunnels in production you should use a pre-created named tunnel by following: https://developers.cloudflare.com/cloudflare-one/connections/connect-apps
# 2026-05-08T23:16:41Z INF Requesting new quick Tunnel on trycloudflare.com...
# 2026-05-08T23:16:46Z INF +--------------------------------------------------------------------------------------------+
# 2026-05-08T23:16:46Z INF |  Your quick Tunnel has been created! Visit it at (it may take some time to be reachable):  |
# 2026-05-08T23:16:46Z INF |  https://virtue-introduces--payment.trycloudflare.com                                      |
#
# ============================================================
# 🌐 TÚNEL ATIVO!
# 📎 URL pública: https://virtue-introduces--payment.trycloudflare.com
#
# Endpoints:
#   GET  https://virtue-introduces--payment.trycloudflare.com/health
#   GET  https://virtue-introduces--payment.trycloudflare.com/models
#   POST https://virtue-introduces--payment.trycloudflare.com/generate
# ============================================================
#
# ⚠️  TOKEN: cs-secret-2026
#
# 📋 Copie esta URL e cole aqui no chat para eu usar!

# %% [markdown]
# ---
#
# ## Como usar
#
# Cole a URL do tunnel aqui no chat. Eu faço a requisição e devolvo a imagem!
#
# ```
# POST /generate
# {
#   "name": "Kira",
#   "creature": "AI / Idol",
#   "emoji": "🎤",
#   "vibe": "Ídolo pop digital.",
#   "humor": 60,
#   "vibeStyle": "expressive"
# }
# ```
